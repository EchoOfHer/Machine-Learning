# %%
import pandas as pd
import joblib
import json as json
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %% [markdown]
# ### Loading data

# %%
data_train = pd.read_csv('../data/salary.train.processed.csv').set_index('id')
data_train
# Out:
#        age-group  education-num  native-country  capitalgain  capitalloss  \
# id
# 26890        3.0           16.0               5          0.0          0.0
# 933          3.0           14.0               5          4.0          0.0
# 25596        2.0           10.0               5          0.0          0.0
# 12949        2.0           13.0               5          0.0          0.0
# 6681         1.0            9.0               5          0.0          0.0
# ...          ...            ...             ...          ...          ...
# 8695         0.0           10.0               5          0.0          0.0
# 2192         2.0           10.0               5          2.0          0.0
# 8250         0.0            9.0               5          0.0          0.0
# 18511        2.0           14.0               5          0.0          0.0
# 16074        2.0            8.0               0          0.0          0.0
#
#        hoursperweek  occupation_prof-specialty  occupation_tech-support  \
# id
# 26890           3.0                        1.0                      0.0
# 933             3.0                        1.0                      0.0
# 25596           2.0                        0.0                      1.0
# 12949           3.0                        0.0                      0.0
# 6681            2.0                        0.0                      0.0
# ...             ...                        ...                      ...
# 8695            2.0                        1.0                      0.0
# 2192            2.0                        0.0                      0.0
# 8250            2.0                        0.0                      0.0
# 18511           0.0                        0.0                      1.0
# 16074           3.0                        0.0                      0.0
#
#        occupation_exec-managerial  occupation_machine-op-inspct  ...  \
# id                                                               ...
# 26890                         0.0                           0.0  ...
# 933                           0.0                           0.0  ...
# 25596                         0.0                           0.0  ...
# 12949                         1.0                           0.0  ...
# 6681                          0.0                           1.0  ...
# ...                           ...                           ...  ...
# 8695                          0.0                           0.0  ...
# 2192                          0.0                           0.0  ...
# 8250                          0.0                           0.0  ...
# 18511                         0.0                           0.0  ...
# 16074                         1.0                           0.0  ...
#
#        relationship_own-child  relationship_unmarried  race_white  \
# id
# 26890                     1.0                     0.0         1.0
# 933                       0.0                     1.0         1.0
# 25596                     0.0                     1.0         1.0
# 12949                     0.0                     0.0         1.0
# 6681                      0.0                     0.0         1.0
# ...                       ...                     ...         ...
# 8695                      0.0                     0.0         1.0
# 2192                      0.0                     0.0         1.0
# 8250                      0.0                     0.0         0.0
# 18511                     0.0                     0.0         1.0
# 16074                     0.0                     0.0         0.0
#
#        race_amer-indian-eskimo  race_black  race_asian-pac-islander  \
# id
# 26890                      0.0         0.0                      0.0
# 933                        0.0         0.0                      0.0
# 25596                      0.0         0.0                      0.0
# 12949                      0.0         0.0                      0.0
# 6681                       0.0         0.0                      0.0
# ...                        ...         ...                      ...
# 8695                       0.0         0.0                      0.0
# 2192                       0.0         0.0                      0.0
# 8250                       0.0         1.0                      0.0
# 18511                      0.0         0.0                      0.0
# 16074                      0.0         0.0                      1.0
#
#        race_other  sex_male  sex_female  label
# id
# 26890         0.0       1.0         0.0    1.0
# 933           0.0       1.0         0.0    1.0
# 25596         0.0       0.0         1.0    0.0
# 12949         0.0       1.0         0.0    1.0
# 6681          0.0       1.0         0.0    0.0
# ...           ...       ...         ...    ...
# 8695          0.0       1.0         0.0    0.0
# 2192          0.0       1.0         0.0    0.0
# 8250          0.0       1.0         0.0    0.0
# 18511         0.0       1.0         0.0    1.0
# 16074         0.0       1.0         0.0    0.0
#
# [16720 rows x 49 columns]

# %% [markdown]
# ### Split train and Test data

# %%
target = 'label'

X_train = data_train.drop(columns=[target])
y_train = data_train[target]

# %% [markdown]
# ---

# %% [markdown]
# ### Default model

# %% [markdown]
# - Train with default parameter
# ```
# `n_estimators = 100`,
# `random_state = 42`
# ```

# %%
model = RandomForestClassifier(
    # n_estimators=100,
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
joblib.dump(
    value = model,
    filename = './model/model.joblib'
)
# Out:
# ['./model/model.joblib']

# %%
param_df = pd.DataFrame.from_dict(
    model.get_params(),
    orient='index',
    columns=['value']
)
param_df
# Out:
#                           value
# bootstrap                  True
# ccp_alpha                   0.0
# class_weight               None
# criterion                  gini
# max_depth                  None
# max_features               sqrt
# max_leaf_nodes             None
# max_samples                None
# min_impurity_decrease       0.0
# min_samples_leaf              1
# min_samples_split             2
# min_weight_fraction_leaf    0.0
# monotonic_cst              None
# n_estimators                100
# n_jobs                     None
# oob_score                 False
# random_state                 42
# verbose                       0
# warm_start                False

# %%
with open('./model/config.json','w')as f:
    json.dump(
        obj=model.get_params(),
        fp=f,
        indent = 4
)
