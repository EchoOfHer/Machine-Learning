# %%
import pandas
import optuna
import numpy as np
import sklearn.metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold, cross_val_predict

# %% [markdown]
# ### Load data

# %%
data_train_full = pandas.read_csv('../data/salary.train.processed.csv').set_index('id')
data_test_lr = pandas.read_csv('../data/salary.test.processed.csv').set_index('id')

# %% [markdown]
# - split the data

# %%
X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

X_test = data_test_lr.drop(['label'], axis='columns')
y_test = data_test_lr['label']

# %%
def objective(trial):
    C = trial.suggest_float('C', 1e-4, 1e2, log=True)
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2', 'elasticnet'])
    
    l1_ratio = None
    if penalty == 'elasticnet':
        l1_ratio = trial.suggest_float('l1_ratio', 0, 1)
    weight_for_class_1 = trial.suggest_float('weight_for_class_1', 1.0, 5.0)
    class_weight = {0: 1.0, 1: weight_for_class_1}

    pipeline_lr = Pipeline([
        ('scaler', StandardScaler()),
        ('model', LogisticRegression(
            C=C,
            penalty=penalty,
            l1_ratio=l1_ratio,
            solver='saga',
            class_weight=class_weight, 
            random_state=42,
            max_iter=5000,
            n_jobs=-1
        ))
    ])
    
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    y_probs = cross_val_predict(
        pipeline_lr, 
        X_full, 
        y_full, 
        cv=cv, 
        method='predict_proba', 
        n_jobs=-1
    )[:, 1] 

    thresholds = np.linspace(0.01, 0.99, 100)
    best_f1_in_trial = -1
    
    for t in thresholds:
        y_pred_t = (y_probs >= t).astype(int)
        
        f1_t = sklearn.metrics.f1_score(y_full, y_pred_t, average='weighted')
        
        if f1_t > best_f1_in_trial:
            best_f1_in_trial = f1_t
            
    trial.set_user_attr("best_threshold", thresholds[np.argmax([sklearn.metrics.f1_score(y_full, (y_probs >= t).astype(int), average='weighted') for t in thresholds])])
    return best_f1_in_trial

# %% [markdown]
# - Run Optuna

# %%
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)

study.optimize(
    objective, 
    n_trials=100, 
    show_progress_bar=True
)
# Out:
# [I 2025-11-08 22:34:36,344] A new study created in memory with name: no-name-17d630b8-25bc-402a-b7aa-4bdeb15cb40a
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-08 22:35:04,460] Trial 0 finished with value: 0.8141272117630708 and parameters: {'C': 11.865828155244406, 'penalty': 'l2', 'weight_for_class_1': 4.000386305906321}. Best is trial 0 with value: 0.8141272117630708.
# [I 2025-11-08 22:35:08,213] Trial 1 finished with value: 0.791153076546506 and parameters: {'C': 0.0005654339031528567, 'penalty': 'elasticnet', 'l1_ratio': 0.8700932679391642, 'weight_for_class_1': 2.351294391609015}. Best is trial 0 with value: 0.8141272117630708.
# [I 2025-11-08 22:35:32,611] Trial 2 finished with value: 0.8140942158397853 and parameters: {'C': 74.40528755218807, 'penalty': 'l1', 'weight_for_class_1': 4.746921978412088}. Best is trial 0 with value: 0.8141272117630708.
# [I 2025-11-08 22:35:39,776] Trial 3 finished with value: 0.8142720773518896 and parameters: {'C': 0.024256272439582144, 'penalty': 'l1', 'weight_for_class_1': 2.8899960806948624}. Best is trial 3 with value: 0.8142720773518896.
. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:42:13,896] Trial 39 finished with value: 0.8146661143610757 and parameters: {'C': 0.08122301256315274, 'penalty': 'l1', 'weight_for_class_1': 2.050255918978376}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:42:24,111] Trial 40 finished with value: 0.8153688063372577 and parameters: {'C': 0.27741984803744335, 'penalty': 'l2', 'weight_for_class_1': 1.7259825579830503}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:42:31,547] Trial 41 finished with value: 0.8155963786850179 and parameters: {'C': 0.048540874640931334, 'penalty': 'l2', 'weight_for_class_1': 1.4784095234312224}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:42:38,202] Trial 42 finished with value: 0.8139686325679176 and parameters: {'C': 0.043527516189565976, 'penalty': 'l2', 'weight_for_class_1': 4.2346368018613}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:42:47,706] Trial 43 finished with value: 0.8155807656732005 and parameters: {'C': 0.10371948980609454, 'penalty': 'l2', 'weight_for_class_1': 1.1830803267456336}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:42:52,214] Trial 44 finished with value: 0.8143289734164191 and parameters: {'C': 0.00877764125045169, 'penalty': 'l2', 'weight_for_class_1': 1.6517498228929945}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:43:03,495] Trial 45 finished with value: 0.815657657843974 and parameters: {'C': 0.4269295881852236, 'penalty': 'l2', 'weight_for_class_1': 1.1889307447401676}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:43:16,951] Trial 46 finished with value: 0.8154038552386955 and parameters: {'C': 5.86915580546039, 'penalty': 'l2', 'weight_for_class_1': 1.2662640166413173}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:44:48,378] Trial 47 finished with value: 0.8153489983841458 and parameters: {'C': 1.411666218630022, 'penalty': 'l1', 'weight_for_class_1': 1.0406024869548296}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:44:57,469] Trial 48 finished with value: 0.8155797012754427 and parameters: {'C': 0.48694660844052, 'penalty': 'l2', 'weight_for_class_1': 1.9956190063209076}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:45:12,715] Trial 49 finished with value: 0.8154157555578383 and parameters: {'C': 0.7982182145681379, 'penalty': 'l2', 'weight_for_class_1': 1.709840662573759}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:45:22,791] Trial 50 finished with value: 0.814821908883422 and parameters: {'C': 0.020594245254620943, 'penalty': 'l2', 'weight_for_class_1': 1.0152541290352908}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:45:35,052] Trial 51 finished with value: 0.8155330014863503 and parameters: {'C': 0.17554699108653954, 'penalty': 'l2', 'weight_for_class_1': 1.4911155544899357}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:45:45,823] Trial 52 finished with value: 0.8154308258395871 and parameters: {'C': 0.06756964193481506, 'penalty': 'l2', 'weight_for_class_1': 1.166559505747107}. Best is trial 34 with value: 0.8157466361812588.
# [I 2025-11-08 22:45:57,512] Trial 53 finished with value: 0.8158444968496104 and parameters: {'C': 0.3265000362645873, 'penalty': 'l2', 'weight_for_class_1': 1.3963084513738258}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:46:07,779] Trial 54 finished with value: 0.8155752044969734 and parameters: {'C': 1.0822809504919915, 'penalty': 'l2', 'weight_for_class_1': 1.8774334302492295}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:46:17,360] Trial 55 finished with value: 0.8155599115194817 and parameters: {'C': 0.2550790243987652, 'penalty': 'l2', 'weight_for_class_1': 1.2443765309961754}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:47:00,122] Trial 56 finished with value: 0.8155767735941697 and parameters: {'C': 0.40231764609606824, 'penalty': 'elasticnet', 'l1_ratio': 0.9824739990638671, 'weight_for_class_1': 1.5561370806690438}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:47:12,517] Trial 57 finished with value: 0.8153906176945207 and parameters: {'C': 3.4628552941409554, 'penalty': 'l2', 'weight_for_class_1': 1.4432966524609678}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:47:26,215] Trial 58 finished with value: 0.8156320375733591 and parameters: {'C': 22.037371427658563, 'penalty': 'l2', 'weight_for_class_1': 1.8305141050327063}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:47:34,300] Trial 59 finished with value: 0.8150180786324449 and parameters: {'C': 0.16085325746061163, 'penalty': 'l2', 'weight_for_class_1': 2.323895487135017}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:47:41,808] Trial 60 finished with value: 0.8155170421591262 and parameters: {'C': 0.03235562056122562, 'penalty': 'l2', 'weight_for_class_1': 1.2015369594665872}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:47:54,238] Trial 61 finished with value: 0.8155382035377511 and parameters: {'C': 50.09246534428405, 'penalty': 'l2', 'weight_for_class_1': 1.886880288456739}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:48:06,890] Trial 62 finished with value: 0.8155163428895329 and parameters: {'C': 21.111747158961798, 'penalty': 'l2', 'weight_for_class_1': 1.6322918614311868}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:48:21,445] Trial 63 finished with value: 0.8156975909350639 and parameters: {'C': 15.00401402518657, 'penalty': 'l2', 'weight_for_class_1': 1.3687742736111785}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:48:34,526] Trial 64 finished with value: 0.8156823580697072 and parameters: {'C': 6.440484384687713, 'penalty': 'l2', 'weight_for_class_1': 1.3494228445115652}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:48:46,960] Trial 65 finished with value: 0.814056975444387 and parameters: {'C': 7.083073046735199, 'penalty': 'l2', 'weight_for_class_1': 4.879901667397829}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:49:08,352] Trial 66 finished with value: 0.8158007308553373 and parameters: {'C': 10.887952376737145, 'penalty': 'l1', 'weight_for_class_1': 1.3614643323512963}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:49:33,520] Trial 67 finished with value: 0.8155660455750422 and parameters: {'C': 9.82206703006942, 'penalty': 'l1', 'weight_for_class_1': 1.2972600412348523}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:49:59,495] Trial 68 finished with value: 0.8153810979346404 and parameters: {'C': 50.18943226966516, 'penalty': 'l1', 'weight_for_class_1': 1.0057809111413398}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:50:18,446] Trial 69 finished with value: 0.815662084380262 and parameters: {'C': 16.818963835209885, 'penalty': 'l1', 'weight_for_class_1': 1.3217459261457296}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:50:35,198] Trial 70 finished with value: 0.815596405270852 and parameters: {'C': 90.28035873229541, 'penalty': 'l1', 'weight_for_class_1': 1.3954870183635348}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:50:56,845] Trial 71 finished with value: 0.8153963124802824 and parameters: {'C': 12.59351522930162, 'penalty': 'l1', 'weight_for_class_1': 1.176500259084361}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:51:19,131] Trial 72 finished with value: 0.815725109165234 and parameters: {'C': 13.107153643540709, 'penalty': 'l1', 'weight_for_class_1': 1.34469530942671}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:51:38,114] Trial 73 finished with value: 0.8154167925771115 and parameters: {'C': 15.340694930922792, 'penalty': 'l1', 'weight_for_class_1': 1.6171580466632618}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:52:01,056] Trial 74 finished with value: 0.8155878741947742 and parameters: {'C': 37.517640047165074, 'penalty': 'l1', 'weight_for_class_1': 1.3177090551524322}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22:52:18,802] Trial 75 finished with value: 0.8156976130623598 and parameters: {'C': 3.113481863606401, 'penalty': 'l1', 'weight_for_class_1': 1.5311285930993994}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 22
. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 23:00:39,676] Trial 95 finished with value: 0.8154368690273539 and parameters: {'C': 5.034159991131853, 'penalty': 'l1', 'weight_for_class_1': 1.7750912939787007}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 23:00:59,161] Trial 96 finished with value: 0.815440532821436 and parameters: {'C': 20.616776354015325, 'penalty': 'l1', 'weight_for_class_1': 1.6514471894567415}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 23:02:17,421] Trial 97 finished with value: 0.8144921397165292 and parameters: {'C': 0.6893898453527528, 'penalty': 'l1', 'weight_for_class_1': 2.650183531095328}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 23:02:38,802] Trial 98 finished with value: 0.8156180643375693 and parameters: {'C': 33.88170885231679, 'penalty': 'l1', 'weight_for_class_1': 1.4603185452740046}. Best is trial 53 with value: 0.8158444968496104.
# [I 2025-11-08 23:02:55,456] Trial 99 finished with value: 0.8155650068290615 and parameters: {'C': 0.09135424191366391, 'penalty': 'l1', 'weight_for_class_1': 1.0856194042631988}. Best is trial 53 with value: 0.8158444968496104.

# %% [markdown]
# - Set the best params

# %%
best_lr_params = study.best_params
best_threshold = study.best_trial.user_attrs['best_threshold']
final_class_weight = {0: 1.0, 1: best_lr_params.get('weight_for_class_1')}

# %%
final_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(
        C=best_lr_params.get('C'),
        penalty=best_lr_params.get('penalty'),
        l1_ratio=best_lr_params.get('l1_ratio'),
        solver='saga',
        class_weight=final_class_weight, # 👈 ใช้ class_weight ที่จูนได้
        random_state=42,
        max_iter=5000,
        n_jobs=-1
    ))
])

# %% [markdown]
# - Train Pipeline with all data (X_full,y_full)

# %%
final_pipeline.fit(X_full, y_full)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  LogisticRegression(C=0.3265000362645873, max_iter=5000,
#                                     n_jobs=-1, random_state=42,
#                                     solver='saga'))])

# %% [markdown]
# - Predict probabilities on test set

# %%
y_probs_test = final_pipeline.predict_proba(X_test)[:, 1]

# %% [markdown]
# - Predict with best thershold

# %%
y_pred_final = (y_probs_test >= best_threshold).astype(int)

# %%
print("\nLogistic Regression (Optuna-Tuned + Best Threshold) Confusion Matrix:")
print(sklearn.metrics.confusion_matrix(
    y_true=y_test,
    y_pred=y_pred_final
))

report_scores_lr = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=y_pred_final,
    digits=6,
    output_dict=True
)
df_score_lr = pandas.DataFrame(report_scores_lr).transpose()
print("\nLogistic Regression (Optuna-Tuned + Best Threshold) Report:")
print(df_score_lr)
# Out:
# Logistic Regression (Optuna-Tuned + Best Threshold) Confusion Matrix:
# [[2131  285]
#  [ 500 1264]]
#
# Logistic Regression (Optuna-Tuned + Best Threshold) Report:
#               precision    recall  f1-score      support
# 0.0            0.809958  0.882036  0.844462  2416.000000
# 1.0            0.816010  0.716553  0.763055  1764.000000
# accuracy       0.812201  0.812201  0.812201     0.812201
# macro avg      0.812984  0.799295  0.803758  4180.000000
# weighted avg   0.812512  0.812201  0.810107  4180.000000

# %%
best_lr_params
# Out:
# {'C': 0.3265000362645873,
#  'penalty': 'l2',
#  'weight_for_class_1': 1.3963084513738258}
