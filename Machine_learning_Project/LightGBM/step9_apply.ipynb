# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
data_live = pandas.read_csv('../data/salary.live.processed.csv').set_index('id')
data_live.head(5)
# Out:
#        age-group  education-num  native-country  capitalgain  capitalloss  \
# id
# 6111         0.0            7.0               5          0.0          0.0
# 11214        1.0            9.0               3          0.0          0.0
# 5554         4.0            9.0               5          0.0          0.0
# 25131        2.0           14.0               5          0.0          0.0
# 14324        3.0            9.0               5          0.0          0.0
#
#        hoursperweek  occupation_prof-specialty  occupation_tech-support  \
# id
# 6111            2.0                        0.0                      0.0
# 11214           1.0                        0.0                      0.0
# 5554            3.0                        0.0                      0.0
# 25131           2.0                        1.0                      0.0
# 14324           2.0                        0.0                      0.0
#
#        occupation_exec-managerial  occupation_machine-op-inspct  ...  \
# ...

# %% [markdown]
# ### Load model

# %%
model = joblib.load('./model/feature_lgbm+refind.joblib')
model
# Out:
# LGBMClassifier( min_child_weight=0.0021823800720918874,
#                colsample_bytree=0.8423956441953476,
#                learning_rate=0.13980341632956964, max_depth=6,
#                min_child_samples=34, min_split_gain=0.06338689720030768,
#                num_leaves=60, reg_alpha=4.063877184715384e-07,
#                reg_lambda=0.00018495256984555554,
#                scale_pos_weight=1.7351767947949777,
#                subsample=0.7093856152946971)

# %%
model.predict(X = data_live)
# Out:
# [LightGBM] [Warning] min_child_weight is set=0.001, min_child_weight=0.0021823800720918874 will be ignored. Current value: min_child_weight=0.001
# array([0., 0., 1., ..., 0., 1., 0.])

# %%
data_live['prediction']=model.predict(
X = data_live,
)
# Out:
# [LightGBM] [Warning] min_child_weight is set=0.001, min_child_weight=0.0021823800720918874 will be ignored. Current value: min_child_weight=0.001

# %%
data_live.head(10)
# Out:
#        age-group  education-num  native-country  capitalgain  capitalloss  \
# id
# 6111         0.0            7.0               5          0.0          0.0
# 11214        1.0            9.0               3          0.0          0.0
# 5554         4.0            9.0               5          0.0          0.0
# 25131        2.0           14.0               5          0.0          0.0
# 14324        3.0            9.0               5          0.0          0.0
# 26678        1.0            9.0               5          0.0          0.0
# 16233        4.0            9.0               5          0.0          0.0
# 27820        1.0            9.0               5          0.0          0.0
# 26402        3.0            9.0               5          0.0          0.0
# 312          2.0           10.0               4          0.0          0.0
#
#        hoursperweek  occupation_prof-specialty  occupation_tech-support  \
# id
# ...

# %%
prediction_counts = data_live['prediction'].value_counts()
prediction_counts
# Out:
# prediction
# 1.0    3494
# 0.0    3473
# Name: count, dtype: int64

# %%
data_live['prediction']
# Out:
# id
# 6111     0.0
# 11214    0.0
# 5554     1.0
# 25131    1.0
# 14324    1.0
#         ...
# 25998    1.0
# 8375     0.0
# 13888    0.0
# 4159     1.0
# 9658     0.0
# Name: prediction, Length: 6967, dtype: float64

# %%
df_report = pandas.DataFrame(
    data=data_live['prediction'],
    columns=['prediction'],
    index=data_live.index
)
df_report
# Out:
#        prediction
# id
# 6111          0.0
# 11214         0.0
# 5554          1.0
# 25131         1.0
# 14324         1.0
# ...           ...
# 25998         1.0
# 8375          0.0
# 13888         0.0
# 4159          1.0
# 9658          0.0
#
# [6967 rows x 1 columns]

# %%
df_report.to_csv('./results/lgbm_live_report.csv', index=True)
