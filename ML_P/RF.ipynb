# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
# อ่านข้อมูล
data_train = pd.read_csv('./data/salary.train.processed.csv').set_index('id')
data_test = pd.read_csv('./data/salary.test.processed.csv').set_index('id')

# %%
# กำหนด target
target = 'label'

# แยกข้อมูลฝึกและทดสอบ
X_train = data_train.drop(columns=[target])
y_train = data_train[target]
X_test = data_test.drop(columns=[target])
y_test = data_test[target]

# สร้างและฝึกโมเดล Random Forest เริ่มต้น
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# ทดสอบและคำนวณ F1 Score
y_pred = model.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print("\nF1 Score จาก Random Forest เริ่มต้น:", f1)
# Out:
# F1 Score จาก Random Forest เริ่มต้น: 0.7995615745957015

# %%
import pandas
import optuna
import sklearn.metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
import numpy as np

# --- 1. โหลดและเตรียมข้อมูล (เหมือนเดิม) ---
# (ใช้ไฟล์ salary.train.processed.csv เหมือนเดิม)
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # คุณต้องจัดการ error นี้ ในตัวอย่างนี้จะสมมติว่าโหลดไฟล์ได้
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

# หมายเหตุ: Optuna ทำงานได้ดีที่สุดเมื่อใช้ cross-validation
# เราไม่จำเป็นต้องแบ่ง X_train/X_val เหมือนตอนทำ early stopping กับ XGBoost
# เราจะใช้ X_full, y_full ไปเลย
print(f"ใช้ข้อมูลเทรนทั้งหมด {len(y_full)} records สำหรับการจูนด้วย Optuna (K-Fold CV)")

# คำนวณ class_weight สำหรับ RF (RF ใช้ 'class_weight' แทน 'scale_pos_weight')
# 'balanced' เป็นวิธีที่ง่ายและมักจะได้ผลดี
rf_class_weight = 'balanced' 


# --- 2. สร้างฟังก์ชัน Objective (หัวใจของ Optuna) ---

def objective(trial):
    """
    ฟังก์ชันนี้จะถูกเรียกโดย Optuna ในแต่ละ "trial" (การทดลอง)
    trial: คือ object ที่ใช้ในการ "เสนอ" ค่าพารามิเตอร์
    """
    
    # กำหนดช่วงของพารามิเตอร์ที่เราอยากให้ Optuna ไป "สุ่มหา"
    param_rf = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=50),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 14),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'max_features': trial.suggest_float('max_features', 0.1, 1.0) # สุ่มเป็น %
    }
    
    # สร้างโมเดล RF ด้วยพารามิเตอร์ที่ Optuna สุ่มมาให้
    model_rf = RandomForestClassifier(
        **param_rf,
        class_weight=rf_class_weight, # จัดการ imbalance
        random_state=42,
        n_jobs=-1
    )
    
    # ประเมินผลโมเดลด้วย Cross-validation (cv=3 คือ 3-Fold)
    # เราจะใช้ 'f1_weighted' เพราะข้อมูลเรา imbalance
    score = cross_val_score(
        model_rf, 
        X_full, 
        y_full, 
        cv=3,                 # 3-Fold Cross-validation
        scoring='f1_weighted',
        n_jobs=-1
    )
    
    # คืนค่า F1 เฉลี่ยกลับไปให้ Optuna
    f1_avg = np.mean(score)
    return f1_avg

# --- 3. เริ่มการค้นหา (Study) ---

print("\nกำลังเริ่มการค้นหาพารามิเตอร์ด้วย Optuna...")

# สร้าง study object, บอกว่าเราต้องการ 'maximize' (หาค่า F1 สูงสุด)
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)

# สั่งให้เริ่มค้นหา (optimize) โดยเรียก objective 50 ครั้ง
study.optimize(
    objective, 
    n_trials=50,  # จำนวนครั้งที่จะให้ลอง (ยิ่งเยอะยิ่งดี แต่ยิ่งนาน)
    show_progress_bar=True # แสดงแถบความคืบหน้า
)

# --- 4. แสดงผลลัพธ์ ---

print("\n--- Optuna ค้นหาเสร็จสิ้น! ---")

# พารามิเตอร์ที่ดีที่สุดที่หาได้
print("พารามิเตอร์ที่ดีที่สุด (Best Parameters):")
print(study.best_params)

# F1-score ที่ดีที่สุดที่ทำได้ (จากการ cross-validation)
print(f"\nF1-Weighted ที่ดีที่สุด (จากการ CV): {study.best_value:.6f}")


# --- 5. (ขั้นตอนต่อไป) เทรนโมเดลสุดท้ายและประเมินผลบน Test Set ---

print("\nกำลังเทรนโมเดล RF สุดท้ายด้วยพารามิเตอร์ที่ดีที่สุด...")

# ดึงพารามิเตอร์ที่ดีที่สุดมา
best_parameter = study.best_params  # 👈 *** เปลี่ยนชื่อตัวแปรตรงนี้ ***

# สร้างโมเดลสุดท้าย
rf_model_final = RandomForestClassifier(
    **best_parameter,             # 👈 *** และเปลี่ยนตรงนี้ ***
    class_weight=rf_class_weight,
    random_state=42,
    n_jobs=-1
)

# เทรนโมเดลด้วยข้อมูล "ทั้งหมด" (X_full, y_full)
rf_model_final.fit(X_full, y_full)

print("เทรนโมเดลสุดท้ายเสร็จสิ้น! กำลังประเมินผลบน Test Set...")

# โหลดข้อมูล Test (เหมือนโค้ด XGBoost ของคุณ)
data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')
data_test_rf['prediction'] = rf_model_final.predict(data_test_rf.drop(['label'], axis='columns'))

# แสดงผลลัพธ์บน Test Set
print("\nRandom Forest (Optuna-Tuned) Confusion Matrix:")
print(sklearn.metrics.confusion_matrix(
    y_true=data_test_rf['label'],
    y_pred=data_test_rf['prediction']
))

report_scores_rf = sklearn.metrics.classification_report(
    y_true=data_test_rf['label'],
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()
print("\nRandom Forest (Optuna-Tuned) Report:")
print(df_score_rf)
# Out:
# [I 2025-10-21 21:14:15,994] A new study created in memory with name: no-name-040f97ea-02f4-4012-ae3a-bed006734ebb
# ใช้ข้อมูลเทรนทั้งหมด 16720 records สำหรับการจูนด้วย Optuna (K-Fold CV)
#
# กำลังเริ่มการค้นหาพารามิเตอร์ด้วย Optuna...
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-10-21 21:14:23,855] Trial 0 finished with value: 0.8157015386665712 and parameters: {'n_estimators': 350, 'max_depth': 15, 'min_samples_leaf': 9, 'min_samples_split': 12, 'criterion': 'gini', 'max_features': 0.32957025854684774}. Best is trial 0 with value: 0.8157015386665712.
# [I 2025-10-21 21:14:34,258] Trial 1 finished with value: 0.815953247084789 and parameters: {'n_estimators': 550, 'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 5, 'criterion': 'entropy', 'max_features': 0.4562250000206448}. Best is trial 1 with value: 0.815953247084789.
# [I 2025-10-21 21:14:39,529] Trial 2 finished with value: 0.8163769088462364 and parameters: {'n_estimators': 200, 'max_depth': 11, 'min_samples_leaf': 8, 'min_samples_split': 6, 'criterion': 'entropy', 'max_features': 0.4710013414068097}. Best is trial 2 with value: 0.8163769088462364.
# [I 2025-10-21 21:14:42,985] Trial 3 finished with value: 0.7561587614793103 and parameters: {'n_estimators': 850, 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 9, 'criterion': 'entropy', 'max_features': 0.19317852018591225}. Best is trial 2 with value: 0.8163769088462364.
# [I 2025-10-21 21:14:46,491] Trial 4 finished with value: 0.8135551511218407 and parameters: {'n_estimators': 200, 'max_depth': 14, 'min_samples_leaf': 7, 'min_samples_split': 3, 'criterion': 'gini', 'max_features': 0.541798432853254}. Best is trial 2 with value: 0.8163769088462364.
# [I 2025-10-21 21:14:52,546] Trial 5 finished with value: 0.8086203582706776 and parameters: {'n_estimators': 700, 'max_depth': 7, 'min_samples_leaf': 5, 'min_samples_split': 2, 'criterion': 'gini', 'max_features': 0.34941994321984654}. Best is trial 2 with value: 0.8163769088462364.
# [I 2025-10-21 21:15:03,810] Trial 6 finished with value: 0.8152332609114866 and parameters: {'n_estimators': 750, 'max_depth': 13, 'min_samples_leaf': 9, 'min_samples_split': 14, 'criterion': 'gini', 'max_features': 0.5324301273101351}. Best is trial 2 with value: 0.8163769088462364.
# [I 2025-10-21 21:15:11,018] Trial 7 finished with value: 0.814629295222097 and parameters: {'n_estimators': 300, 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 10, 'criterion': 'gini', 'max_features': 0.8499883558144414}. Best is trial 2 with value: 0.8163769088462364.
# [I 2025-10-21 21:15:17,183] Trial 8 finished with value: 0.817321078295663 and parameters: {'n_estimators': 450, 'max_depth': 11, 'min_samples_leaf': 4, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.43175135231127526}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:27,375] Trial 9 finished with value: 0.8141411865551111 and parameters: {'n_estimators': 400, 'max_depth': 14, 'min_samples_leaf': 7, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.8659588203374755}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:41,966] Trial 10 finished with value: 0.8090911702284419 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'min_samples_leaf': 1, 'min_samples_split': 6, 'criterion': 'entropy', 'max_features': 0.7247717449852091}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:43,874] Trial 11 finished with value: 0.8140599440300486 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 7, 'min_samples_split': 6, 'criterion': 'entropy', 'max_features': 0.690232084504777}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:47,193] Trial 12 finished with value: 0.7984906879760568 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 5, 'criterion': 'entropy', 'max_features': 0.2017712400450442}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:48,854] Trial 13 finished with value: 0.8160223896129611 and parameters: {'n_estimators': 100, 'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 7, 'criterion': 'entropy', 'max_features': 0.3744871542730397}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:53,352] Trial 14 finished with value: 0.8146631918809374 and parameters: {'n_estimators': 250, 'max_depth': 9, 'min_samples_leaf': 6, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.6500198277686307}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:15:57,006] Trial 15 finished with value: 0.7904504073679121 and parameters: {'n_estimators': 450, 'max_depth': 5, 'min_samples_leaf': 8, 'min_samples_split': 8, 'criterion': 'entropy', 'max_features': 0.43339037402072783}. Best is trial 8 with value: 0.817321078295663.
# [I 2025-10-21 21:16:03,837] Trial 16 finished with value: 0.8174509155116724 and parameters: {'n_estimators': 650, 'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.2585237363174617}. Best is trial 16 with value: 0.8174509155116724.
# [I 2025-10-21 21:16:07,747] Trial 17 finished with value: 0.7998496798704214 and parameters: {'n_estimators': 650, 'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.10978059223308018}. Best is trial 16 with value: 0.8174509155116724.
# [I 2025-10-21 21:16:13,521] Trial 18 finished with value: 0.8104091425518062 and parameters: {'n_estimators': 650, 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.25733302990877127}. Best is trial 16 with value: 0.8174509155116724.
# [I 2025-10-21 21:16:21,764] Trial 19 finished with value: 0.8175149527529769 and parameters: {'n_estimators': 800, 'max_depth': 12, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.27333086737703804}. Best is trial 19 with value: 0.8175149527529769.
# [I 2025-10-21 21:16:28,936] Trial 20 finished with value: 0.8158074229962539 and parameters: {'n_estimators': 900, 'max_depth': 15, 'min_samples_leaf': 3, 'min_samples_split': 11, 'criterion': 'entropy', 'max_features': 0.14639058828242463}. Best is trial 19 with value: 0.8175149527529769.
# [I 2025-10-21 21:16:34,570] Trial 21 finished with value: 0.8178689210524442 and parameters: {'n_estimators': 550, 'max_depth': 12, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.2617299440363154}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:16:43,254] Trial 22 finished with value: 0.8176781797169662 and parameters: {'n_estimators': 800, 'max_depth': 13, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.26050825800722804}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:16:52,319] Trial 23 finished with value: 0.8178514420715901 and parameters: {'n_estimators': 800, 'max_depth': 13, 'min_samples_leaf': 4, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.30029426048886704}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:03,234] Trial 24 finished with value: 0.8171392984696436 and parameters: {'n_estimators': 950, 'max_depth': 13, 'min_samples_leaf': 5, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.3066096649423622}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:10,404] Trial 25 finished with value: 0.8165063601352083 and parameters: {'n_estimators': 800, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.1907669678519365}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:17,061] Trial 26 finished with value: 0.8162132407661643 and parameters: {'n_estimators': 600, 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.3885363069301938}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:22,162] Trial 27 finished with value: 0.8113654023527053 and parameters: {'n_estimators': 750, 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.11954847194358031}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:40,010] Trial 28 finished with value: 0.8168150274837728 and parameters: {'n_estimators': 900, 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.620396244359248}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:46,674] Trial 29 finished with value: 0.8169455598095438 and parameters: {'n_estimators': 550, 'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 8, 'criterion': 'gini', 'max_features': 0.3170148736101635}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:17:54,666] Trial 30 finished with value: 0.8109479913440379 and parameters: {'n_estimators': 1000, 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 13, 'criterion': 'entropy', 'max_features': 0.20722377183941812}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:03,150] Trial 31 finished with value: 0.8173288435211855 and parameters: {'n_estimators': 800, 'max_depth': 12, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.28127088793748384}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:11,253] Trial 32 finished with value: 0.8162748646963963 and parameters: {'n_estimators': 850, 'max_depth': 12, 'min_samples_leaf': 4, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.24546805378501935}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:20,651] Trial 33 finished with value: 0.8177177192006466 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_leaf': 3, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.3442639386436206}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:30,496] Trial 34 finished with value: 0.8173511622553103 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_leaf': 3, 'min_samples_split': 5, 'criterion': 'entropy', 'max_features': 0.37782702767024967}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:40,854] Trial 35 finished with value: 0.8168691243133996 and parameters: {'n_estimators': 600, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.46189024080759267}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:50,162] Trial 36 finished with value: 0.8164817921672683 and parameters: {'n_estimators': 550, 'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.4979623735281944}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:56,171] Trial 37 finished with value: 0.8151599413578062 and parameters: {'n_estimators': 750, 'max_depth': 13, 'min_samples_leaf': 5, 'min_samples_split': 2, 'criterion': 'gini', 'max_features': 0.17442754840123015}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:18:59,634] Trial 38 finished with value: 0.7596401542312754 and parameters: {'n_estimators': 700, 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.33014933579505745}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:19:12,880] Trial 39 finished with value: 0.8172782165897979 and parameters: {'n_estimators': 850, 'max_depth': 15, 'min_samples_leaf': 3, 'min_samples_split': 7, 'criterion': 'gini', 'max_features': 0.40648653249851296}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:19:40,763] Trial 40 finished with value: 0.81460531171459 and parameters: {'n_estimators': 900, 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.942271487634774}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:19:48,653] Trial 41 finished with value: 0.8166916324208304 and parameters: {'n_estimators': 800, 'max_depth': 12, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.23393945264292648}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:19:58,286] Trial 42 finished with value: 0.8178436287999581 and parameters: {'n_estimators': 750, 'max_depth': 14, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.29239254946387766}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:06,234] Trial 43 finished with value: 0.8171336984157754 and parameters: {'n_estimators': 600, 'max_depth': 14, 'min_samples_leaf': 5, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.3456983529225826}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:14,572] Trial 44 finished with value: 0.8173673852690534 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_leaf': 4, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.2949254846996664}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:23,071] Trial 45 finished with value: 0.8161690294722296 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_leaf': 3, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 0.5019967143343105}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:30,291] Trial 46 finished with value: 0.8170873007245955 and parameters: {'n_estimators': 750, 'max_depth': 14, 'min_samples_leaf': 5, 'min_samples_split': 10, 'criterion': 'entropy', 'max_features': 0.22525023781846015}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:32,945] Trial 47 finished with value: 0.8149103235963436 and parameters: {'n_estimators': 350, 'max_depth': 15, 'min_samples_leaf': 6, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.14749151040544936}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:42,949] Trial 48 finished with value: 0.8170368424696935 and parameters: {'n_estimators': 850, 'max_depth': 11, 'min_samples_leaf': 4, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.3620498407371716}. Best is trial 21 with value: 0.8178689210524442.
# [I 2025-10-21 21:20:53,359] Trial 49 finished with value: 0.8173512961209166 and parameters: {'n_estimators': 700, 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.41662177734440387}. Best is trial 21 with value: 0.8178689210524442.
#
# --- Optuna ค้นหาเสร็จสิ้น! ---
# พารามิเตอร์ที่ดีที่สุด (Best Parameters):
# {'n_estimators': 550, 'max_depth': 12, 'min_samples_leaf': 4, 'min_samples_split': 2, 'criterion': 'entropy', 'max_features': 0.2617299440363154}
#
# F1-Weighted ที่ดีที่สุด (จากการ CV): 0.817869
#
# กำลังเทรนโมเดล RF สุดท้ายด้วยพารามิเตอร์ที่ดีที่สุด...
# เทรนโมเดลสุดท้ายเสร็จสิ้น! กำลังประเมินผลบน Test Set...
#
# Random Forest (Optuna-Tuned) Confusion Matrix:
# [[1906  510]
#  [ 240 1524]]
#
# Random Forest (Optuna-Tuned) Report:
#               precision    recall  f1-score      support
# 0.0            0.888164  0.788907  0.835598  2416.000000
# 1.0            0.749263  0.863946  0.802528  1764.000000
# accuracy       0.820574  0.820574  0.820574     0.820574
# macro avg      0.818713  0.826426  0.819063  4180.000000
# weighted avg   0.829546  0.820574  0.821642  4180.000000

# %% [markdown]
# ### class weight

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter
# --- 3. Create and Train the Final Model ---
print("\nTraining final RF model with best params and class weighting...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    class_weight='balanced_subsample', # 👈 Here is the class weight
    random_state=42,
    n_jobs=-1
)

# Train the model on the full training dataset
rf_model_final.fit(X_full, y_full)
print("Model training complete.")

# --- 4. Evaluate on Test Data ---
print("\nEvaluating model on test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')
data_test_rf['prediction'] = rf_model_final.predict(data_test_rf.drop(['label'], axis='columns'))

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=data_test_rf['label'],
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + Weighted) Report:")
print(df_score_rf)
# Out:
# Training final RF model with best params and class weighting...
# Model training complete.
#
# Evaluating model on test data...
#
# Random Forest (Tuned + Weighted) Report:
#               precision    recall  f1-score      support
# 0.0            0.888681  0.786424  0.834431  2416.000000
# 1.0            0.747307  0.865079  0.801892  1764.000000
# accuracy       0.819617  0.819617  0.819617     0.819617
# macro avg      0.817994  0.825752  0.818162  4180.000000
# weighted avg   0.829020  0.819617  0.820699  4180.000000

# %% [markdown]
# ### class SMOTE

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE  # 👈 1. Import SMOTE

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply SMOTE to the Training Data ---
print("\nApplying SMOTE to the training data...")
smote = SMOTE(random_state=42, n_jobs=-1)
X_resampled, y_resampled = smote.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")


# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on SMOTEd data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # class_weight='balanced_subsample', # 👈 2. REMOVE class_weight
    random_state=42,
    n_jobs=-1
)

# 4. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 5. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')

# IMPORTANT: Do NOT apply SMOTE to the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + SMOTE) Report:")
print(df_score_rf)
# Out:
# Original training data shape: (16720, 89)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying SMOTE to the training data...
# New resampled training data shape: (19438, 89)
# New resampled label distribution:
# label
# 1.0    9719
# 0.0    9719
# Name: count, dtype: int64
#
# Training final RF model on SMOTEd data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + SMOTE) Report:
#               precision    recall  f1-score     support
# 0.0            0.884138  0.795944  0.837726  2416.00000
# 1.0            0.754115  0.857143  0.802335  1764.00000
# accuracy       0.821770  0.821770  0.821770     0.82177
# macro avg      0.819126  0.826543  0.820030  4180.00000
# weighted avg   0.829267  0.821770  0.822791  4180.00000

# %% [markdown]
# ### SMOTETomek

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.combine import SMOTETomek

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']  # 👈 *** THIS IS THE FIX ***

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply SMOTETomek to the Training Data ---
print("\nApplying SMOTETomek to the training data...")
# Note: SMOTETomek can take a bit longer than plain SMOTE
smt = SMOTETomek(random_state=42, n_jobs=-1)
X_resampled, y_resampled = smt.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")

# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on SMOTETomek data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # ⚠️ NO 'class_weight' here
    random_state=42,
    n_jobs=-1
)

# 5. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 6. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')

# IMPORTANT: Do NOT resample the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + SMOTETomek) Report:")
print(df_score_rf)
# Out:
# Original training data shape: (16720, 89)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying SMOTETomek to the training data...
# New resampled training data shape: (17828, 89)
# New resampled label distribution:
# label
# 1.0    8914
# 0.0    8914
# Name: count, dtype: int64
#
# Training final RF model on SMOTETomek data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + SMOTETomek) Report:
#               precision    recall  f1-score      support
# 0.0            0.882891  0.798841  0.838766  2416.000000
# 1.0            0.756269  0.854875  0.802555  1764.000000
# accuracy       0.822488  0.822488  0.822488     0.822488
# macro avg      0.819580  0.826858  0.820660  4180.000000
# weighted avg   0.829455  0.822488  0.823484  4180.000000

# %% [markdown]
# ### ADASYN (Adaptive Synthetic Sampling)

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.over_sampling import ADASYN  # 👈 1. Import ADASYN

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply ADASYN to the Training Data ---
print("\nApplying ADASYN to the training data...")
ada = ADASYN(random_state=42, n_jobs=-1)
X_resampled, y_resampled = ada.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")
# Note: The counts might not be perfectly equal, as ADASYN's generation is adaptive.


# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on ADASYN data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # ⚠️ NO 'class_weight' here
    random_state=42,
    n_jobs=-1
)

# 5. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 6. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')

# IMPORTANT: Do NOT resample the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + ADASYN) Report:")
print(df_score_rf)
# Out:
# Original training data shape: (16720, 89)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying ADASYN to the training data...
# New resampled training data shape: (19445, 89)
# New resampled label distribution:
# label
# 1.0    9726
# 0.0    9719
# Name: count, dtype: int64
#
# Training final RF model on ADASYN data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + ADASYN) Report:
#               precision    recall  f1-score      support
# 0.0            0.898931  0.765728  0.827000  2416.000000
# 1.0            0.733270  0.882086  0.800823  1764.000000
# accuracy       0.814833  0.814833  0.814833     0.814833
# macro avg      0.816101  0.823907  0.813912  4180.000000
# weighted avg   0.829021  0.814833  0.815954  4180.000000
