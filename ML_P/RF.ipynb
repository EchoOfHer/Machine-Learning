# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
# อ่านข้อมูล
data_train = pd.read_csv('./data/salary.train.processed.csv').set_index('id')
data_test = pd.read_csv('./data/salary.test.processed.csv').set_index('id')

# %%
# กำหนด target
target = 'label'

# แยกข้อมูลฝึกและทดสอบ
X_train = data_train.drop(columns=[target])
y_train = data_train[target]
X_test = data_test.drop(columns=[target])
y_test = data_test[target]

# สร้างและฝึกโมเดล Random Forest เริ่มต้น
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# ทดสอบและคำนวณ F1 Score
y_pred = model.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print("\nF1 Score จาก Random Forest เริ่มต้น:", f1)
# Out:
# F1 Score จาก Random Forest เริ่มต้น: 0.8204091782669011

# %%
import pandas
import optuna
import sklearn.metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
import numpy as np

# --- 1. โหลดและเตรียมข้อมูล (เหมือนเดิม) ---
# (ใช้ไฟล์ salary.train.processed.csv เหมือนเดิม)
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # คุณต้องจัดการ error นี้ ในตัวอย่างนี้จะสมมติว่าโหลดไฟล์ได้
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

# หมายเหตุ: Optuna ทำงานได้ดีที่สุดเมื่อใช้ cross-validation
# เราไม่จำเป็นต้องแบ่ง X_train/X_val เหมือนตอนทำ early stopping กับ XGBoost
# เราจะใช้ X_full, y_full ไปเลย
print(f"ใช้ข้อมูลเทรนทั้งหมด {len(y_full)} records สำหรับการจูนด้วย Optuna (K-Fold CV)")

# คำนวณ class_weight สำหรับ RF (RF ใช้ 'class_weight' แทน 'scale_pos_weight')
# 'balanced' เป็นวิธีที่ง่ายและมักจะได้ผลดี
rf_class_weight = 'balanced' 


# --- 2. สร้างฟังก์ชัน Objective (หัวใจของ Optuna) ---

def objective(trial):
    """
    ฟังก์ชันนี้จะถูกเรียกโดย Optuna ในแต่ละ "trial" (การทดลอง)
    trial: คือ object ที่ใช้ในการ "เสนอ" ค่าพารามิเตอร์
    """
    
    # กำหนดช่วงของพารามิเตอร์ที่เราอยากให้ Optuna ไป "สุ่มหา"
    param_rf = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=50),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 14),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'max_features': trial.suggest_float('max_features', 0.1, 1.0) # สุ่มเป็น %
    }
    
    # สร้างโมเดล RF ด้วยพารามิเตอร์ที่ Optuna สุ่มมาให้
    model_rf = RandomForestClassifier(
        **param_rf,
        class_weight=rf_class_weight, # จัดการ imbalance
        random_state=42,
        n_jobs=-1
    )
    
    # ประเมินผลโมเดลด้วย Cross-validation (cv=3 คือ 3-Fold)
    # เราจะใช้ 'f1_weighted' เพราะข้อมูลเรา imbalance
    score = cross_val_score(
        model_rf, 
        X_full, 
        y_full, 
        cv=3,                 # 3-Fold Cross-validation
        scoring='f1_weighted',
        n_jobs=-1
    )
    
    # คืนค่า F1 เฉลี่ยกลับไปให้ Optuna
    f1_avg = np.mean(score)
    return f1_avg

# --- 3. เริ่มการค้นหา (Study) ---

print("\nกำลังเริ่มการค้นหาพารามิเตอร์ด้วย Optuna...")

# สร้าง study object, บอกว่าเราต้องการ 'maximize' (หาค่า F1 สูงสุด)
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)

# สั่งให้เริ่มค้นหา (optimize) โดยเรียก objective 50 ครั้ง
study.optimize(
    objective, 
    n_trials=50,  # จำนวนครั้งที่จะให้ลอง (ยิ่งเยอะยิ่งดี แต่ยิ่งนาน)
    show_progress_bar=True # แสดงแถบความคืบหน้า
)

# --- 4. แสดงผลลัพธ์ ---

print("\n--- Optuna ค้นหาเสร็จสิ้น! ---")

# พารามิเตอร์ที่ดีที่สุดที่หาได้
print("พารามิเตอร์ที่ดีที่สุด (Best Parameters):")
print(study.best_params)

# F1-score ที่ดีที่สุดที่ทำได้ (จากการ cross-validation)
print(f"\nF1-Weighted ที่ดีที่สุด (จากการ CV): {study.best_value:.6f}")


# --- 5. (ขั้นตอนต่อไป) เทรนโมเดลสุดท้ายและประเมินผลบน Test Set ---

print("\nกำลังเทรนโมเดล RF สุดท้ายด้วยพารามิเตอร์ที่ดีที่สุด...")

# ดึงพารามิเตอร์ที่ดีที่สุดมา
best_parameter = study.best_params  # 👈 *** เปลี่ยนชื่อตัวแปรตรงนี้ ***

# สร้างโมเดลสุดท้าย
rf_model_final = RandomForestClassifier(
    **best_parameter,             # 👈 *** และเปลี่ยนตรงนี้ ***
    class_weight=rf_class_weight,
    random_state=42,
    n_jobs=-1
)

# เทรนโมเดลด้วยข้อมูล "ทั้งหมด" (X_full, y_full)
rf_model_final.fit(X_full, y_full)

print("เทรนโมเดลสุดท้ายเสร็จสิ้น! กำลังประเมินผลบน Test Set...")

# โหลดข้อมูล Test (เหมือนโค้ด XGBoost ของคุณ)
data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')
data_test_rf['prediction'] = rf_model_final.predict(data_test_rf.drop(['label'], axis='columns'))

# แสดงผลลัพธ์บน Test Set
print("\nRandom Forest (Optuna-Tuned) Confusion Matrix:")
print(sklearn.metrics.confusion_matrix(
    y_true=data_test_rf['label'],
    y_pred=data_test_rf['prediction']
))

report_scores_rf = sklearn.metrics.classification_report(
    y_true=data_test_rf['label'],
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()
print("\nRandom Forest (Optuna-Tuned) Report:")
print(df_score_rf)
# Out:
# [I 2025-10-24 03:16:36,330] A new study created in memory with name: no-name-6e105ef2-cdc5-4e1e-a64f-d358857f3db5
# ใช้ข้อมูลเทรนทั้งหมด 16720 records สำหรับการจูนด้วย Optuna (K-Fold CV)
#
# กำลังเริ่มการค้นหาพารามิเตอร์ด้วย Optuna...
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-10-24 03:17:17,974] Trial 0 finished with value: 0.8125799448755817 and parameters: {'n_estimators': 1000, 'max_depth': 13, 'min_samples_leaf': 6, 'min_samples_split': 8, 'criterion': 'entropy', 'max_features': 0.9286682738075865}. Best is trial 0 with value: 0.8125799448755817.
# [I 2025-10-24 03:17:26,543] Trial 1 finished with value: 0.7928128331241687 and parameters: {'n_estimators': 900, 'max_depth': 11, 'min_samples_leaf': 4, 'min_samples_split': 13, 'criterion': 'entropy', 'max_features': 0.10134367838906444}. Best is trial 0 with value: 0.8125799448755817.
# [I 2025-10-24 03:17:33,054] Trial 2 finished with value: 0.8177881649291437 and parameters: {'n_estimators': 350, 'max_depth': 11, 'min_samples_leaf': 2, 'min_samples_split': 4, 'criterion': 'gini', 'max_features': 0.34672294690973116}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:17:45,007] Trial 3 finished with value: 0.8138635249040292 and parameters: {'n_estimators': 400, 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 8, 'criterion': 'gini', 'max_features': 0.8104471637566507}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:17:54,422] Trial 4 finished with value: 0.8148490696658389 and parameters: {'n_estimators': 550, 'max_depth': 9, 'min_samples_leaf': 4, 'min_samples_split': 9, 'criterion': 'entropy', 'max_features': 0.475956977377451}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:17:56,833] Trial 5 finished with value: 0.7736651955860294 and parameters: {'n_estimators': 350, 'max_depth': 4, 'min_samples_leaf': 8, 'min_samples_split': 4, 'criterion': 'gini', 'max_features': 0.3784669149932408}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:18:15,699] Trial 6 finished with value: 0.8138419902832187 and parameters: {'n_estimators': 650, 'max_depth': 12, 'min_samples_leaf': 6, 'min_samples_split': 3, 'criterion': 'entropy', 'max_features': 0.7481395596206541}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:18:29,027] Trial 7 finished with value: 0.8079728431813243 and parameters: {'n_estimators': 850, 'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 13, 'criterion': 'gini', 'max_features': 0.8046029145310744}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:18:29,606] Trial 8 finished with value: 0.7554168177256297 and parameters: {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 10, 'min_samples_split': 13, 'criterion': 'entropy', 'max_features': 0.1906949773338375}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:18:34,064] Trial 9 finished with value: 0.8112441147670446 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_leaf': 9, 'min_samples_split': 11, 'criterion': 'entropy', 'max_features': 0.4419457825233186}. Best is trial 2 with value: 0.8177881649291437.
# [I 2025-10-24 03:18:35,500] Trial 10 finished with value: 0.8184981293673305 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.2820803340688387}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:18:37,615] Trial 11 finished with value: 0.8183545580839655 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.27032656831293056}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:18:39,017] Trial 12 finished with value: 0.8164188538853602 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.2401915622477008}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:18:43,398] Trial 13 finished with value: 0.8143587433374279 and parameters: {'n_estimators': 200, 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 6, 'criterion': 'gini', 'max_features': 0.5383941793152847}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:18:56,323] Trial 14 finished with value: 0.8145327684678095 and parameters: {'n_estimators': 550, 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 2, 'criterion': 'gini', 'max_features': 0.6444084818987783}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:18:58,946] Trial 15 finished with value: 0.8178884025129726 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'criterion': 'gini', 'max_features': 0.2839150368238281}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:00,406] Trial 16 finished with value: 0.7984612919015069 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 6, 'criterion': 'gini', 'max_features': 0.11159204720627763}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:10,118] Trial 17 finished with value: 0.8179935451887567 and parameters: {'n_estimators': 650, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 9, 'criterion': 'gini', 'max_features': 0.33650128583618255}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:11,698] Trial 18 finished with value: 0.8098180639423926 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 7, 'min_samples_split': 2, 'criterion': 'gini', 'max_features': 0.5888649058199387}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:16,231] Trial 19 finished with value: 0.8165407240934025 and parameters: {'n_estimators': 450, 'max_depth': 14, 'min_samples_leaf': 3, 'min_samples_split': 7, 'criterion': 'gini', 'max_features': 0.19658137512081036}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:20,628] Trial 20 finished with value: 0.8159416926693188 and parameters: {'n_estimators': 250, 'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.45203513559500647}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:29,582] Trial 21 finished with value: 0.8184142913197658 and parameters: {'n_estimators': 700, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 11, 'criterion': 'gini', 'max_features': 0.3158427313546388}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:38,396] Trial 22 finished with value: 0.8179310136598491 and parameters: {'n_estimators': 750, 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 11, 'criterion': 'gini', 'max_features': 0.2765323215004892}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:49,774] Trial 23 finished with value: 0.8178202314653236 and parameters: {'n_estimators': 750, 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 11, 'criterion': 'gini', 'max_features': 0.3860138243149615}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:19:54,124] Trial 24 finished with value: 0.8147389533498369 and parameters: {'n_estimators': 500, 'max_depth': 12, 'min_samples_leaf': 1, 'min_samples_split': 10, 'criterion': 'gini', 'max_features': 0.18612985493573658}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:20:02,239] Trial 25 finished with value: 0.8175795501493482 and parameters: {'n_estimators': 650, 'max_depth': 14, 'min_samples_leaf': 3, 'min_samples_split': 14, 'criterion': 'gini', 'max_features': 0.2891152583737547}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:20:15,370] Trial 26 finished with value: 0.8164947152120607 and parameters: {'n_estimators': 750, 'max_depth': 12, 'min_samples_leaf': 2, 'min_samples_split': 7, 'criterion': 'gini', 'max_features': 0.5127265223622378}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:20:17,795] Trial 27 finished with value: 0.8172305088706873 and parameters: {'n_estimators': 150, 'max_depth': 13, 'min_samples_leaf': 5, 'min_samples_split': 4, 'criterion': 'gini', 'max_features': 0.4083540209903174}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:20:24,322] Trial 28 finished with value: 0.8137411533819842 and parameters: {'n_estimators': 250, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 3, 'criterion': 'gini', 'max_features': 0.6186542316906822}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:00,735] Trial 29 finished with value: 0.8142160492308923 and parameters: {'n_estimators': 950, 'max_depth': 13, 'min_samples_leaf': 2, 'min_samples_split': 7, 'criterion': 'entropy', 'max_features': 0.9251598678813577}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:08,766] Trial 30 finished with value: 0.8139692048519335 and parameters: {'n_estimators': 1000, 'max_depth': 14, 'min_samples_leaf': 7, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 0.14342244572249585}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:17,720] Trial 31 finished with value: 0.8177596822066184 and parameters: {'n_estimators': 650, 'max_depth': 13, 'min_samples_leaf': 1, 'min_samples_split': 10, 'criterion': 'gini', 'max_features': 0.3223470634081291}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:26,916] Trial 32 finished with value: 0.8168463322782026 and parameters: {'n_estimators': 850, 'max_depth': 12, 'min_samples_leaf': 1, 'min_samples_split': 9, 'criterion': 'gini', 'max_features': 0.23938256220651843}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:36,736] Trial 33 finished with value: 0.8158659155497494 and parameters: {'n_estimators': 700, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 12, 'criterion': 'gini', 'max_features': 0.3565397122808976}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:45,185] Trial 34 finished with value: 0.8172082364211977 and parameters: {'n_estimators': 600, 'max_depth': 11, 'min_samples_leaf': 4, 'min_samples_split': 9, 'criterion': 'gini', 'max_features': 0.32700018772114015}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:21:52,666] Trial 35 finished with value: 0.8171972755093145 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_leaf': 3, 'min_samples_split': 10, 'criterion': 'entropy', 'max_features': 0.2661782773983022}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:22:00,532] Trial 36 finished with value: 0.8167198124378997 and parameters: {'n_estimators': 400, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 8, 'criterion': 'gini', 'max_features': 0.4217257308313148}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:22:14,999] Trial 37 finished with value: 0.8156019529835711 and parameters: {'n_estimators': 850, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 12, 'criterion': 'gini', 'max_features': 0.5009418616844259}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:22:25,507] Trial 38 finished with value: 0.8178741465573656 and parameters: {'n_estimators': 600, 'max_depth': 14, 'min_samples_leaf': 4, 'min_samples_split': 8, 'criterion': 'entropy', 'max_features': 0.3457649882223632}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:22:29,245] Trial 39 finished with value: 0.7684478952185098 and parameters: {'n_estimators': 800, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'criterion': 'gini', 'max_features': 0.16064899081928236}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:22:32,649] Trial 40 finished with value: 0.8160391519536464 and parameters: {'n_estimators': 350, 'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 9, 'criterion': 'gini', 'max_features': 0.22068348934491644}. Best is trial 10 with value: 0.8184981293673305.
# [I 2025-10-24 03:22:42,022] Trial 41 finished with value: 0.8186973320341989 and parameters: {'n_estimators': 750, 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 11, 'criterion': 'gini', 'max_features': 0.2937476124130143}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:22:51,523] Trial 42 finished with value: 0.8180265653078913 and parameters: {'n_estimators': 700, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 12, 'criterion': 'gini', 'max_features': 0.30766969647802045}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:03,101] Trial 43 finished with value: 0.8180719367268395 and parameters: {'n_estimators': 700, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 14, 'criterion': 'gini', 'max_features': 0.3077364047697232}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:18,516] Trial 44 finished with value: 0.8177969020883366 and parameters: {'n_estimators': 900, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 14, 'criterion': 'gini', 'max_features': 0.3790378886519704}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:24,980] Trial 45 finished with value: 0.8083965776488151 and parameters: {'n_estimators': 800, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 13, 'criterion': 'entropy', 'max_features': 0.10229014120036009}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:26,969] Trial 46 finished with value: 0.8173426754047067 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 14, 'criterion': 'gini', 'max_features': 0.24024838928041967}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:34,349] Trial 47 finished with value: 0.8166604351098911 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 13, 'criterion': 'gini', 'max_features': 0.20740626014537517}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:42,381] Trial 48 finished with value: 0.8134369537835687 and parameters: {'n_estimators': 600, 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 3, 'criterion': 'gini', 'max_features': 0.4689691387062459}. Best is trial 41 with value: 0.8186973320341989.
# [I 2025-10-24 03:23:44,217] Trial 49 finished with value: 0.8134271792443628 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_leaf': 3, 'min_samples_split': 11, 'criterion': 'entropy', 'max_features': 0.1513687195964705}. Best is trial 41 with value: 0.8186973320341989.
#
# --- Optuna ค้นหาเสร็จสิ้น! ---
# พารามิเตอร์ที่ดีที่สุด (Best Parameters):
# {'n_estimators': 750, 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 11, 'criterion': 'gini', 'max_features': 0.2937476124130143}
#
# F1-Weighted ที่ดีที่สุด (จากการ CV): 0.818697
#
# กำลังเทรนโมเดล RF สุดท้ายด้วยพารามิเตอร์ที่ดีที่สุด...
# เทรนโมเดลสุดท้ายเสร็จสิ้น! กำลังประเมินผลบน Test Set...
#
# Random Forest (Optuna-Tuned) Confusion Matrix:
# [[1918  498]
#  [ 247 1517]]
#
# Random Forest (Optuna-Tuned) Report:
#               precision    recall  f1-score     support
# 0.0            0.885912  0.793874  0.837372  2416.00000
# 1.0            0.752854  0.859977  0.802858  1764.00000
# accuracy       0.821770  0.821770  0.821770     0.82177
# macro avg      0.819383  0.826926  0.820115  4180.00000
# weighted avg   0.829760  0.821770  0.822807  4180.00000

# %%
print(best_parameter)
# Out:
# {'n_estimators': 750, 'max_depth': 14, 'min_samples_leaf': 1, 'min_samples_split': 11, 'criterion': 'gini', 'max_features': 0.2937476124130143}

# %% [markdown]
# ### class weight

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter
# --- 3. Create and Train the Final Model ---
print("\nTraining final RF model with best params and class weighting...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    class_weight='balanced_subsample', # 👈 Here is the class weight
    random_state=42,
    n_jobs=-1
)

# Train the model on the full training dataset
rf_model_final.fit(X_full, y_full)
print("Model training complete.")

# --- 4. Evaluate on Test Data ---
print("\nEvaluating model on test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')
data_test_rf['prediction'] = rf_model_final.predict(data_test_rf.drop(['label'], axis='columns'))

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=data_test_rf['label'],
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + Weighted) Report:")
print(df_score_rf)
# Out:
# Training final RF model with best params and class weighting...
# Model training complete.
#
# Evaluating model on test data...
#
# Random Forest (Tuned + Weighted) Report:
#               precision    recall  f1-score      support
# 0.0            0.884633  0.793460  0.836570  2416.000000
# 1.0            0.752111  0.858277  0.801694  1764.000000
# accuracy       0.820813  0.820813  0.820813     0.820813
# macro avg      0.818372  0.825868  0.819132  4180.000000
# weighted avg   0.828708  0.820813  0.821852  4180.000000

# %% [markdown]
# ### class SMOTE

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE  # 👈 1. Import SMOTE

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply SMOTE to the Training Data ---
print("\nApplying SMOTE to the training data...")
smote = SMOTE(random_state=42, n_jobs=-1)
X_resampled, y_resampled = smote.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")


# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on SMOTEd data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # class_weight='balanced_subsample', # 👈 2. REMOVE class_weight
    random_state=42,
    n_jobs=-1
)

# 4. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 5. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')

# IMPORTANT: Do NOT apply SMOTE to the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + SMOTE) Report:")
print(df_score_rf)
# Out:
# Original training data shape: (16720, 56)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying SMOTE to the training data...
# c:\Users\natth\anaconda3\Lib\site-packages\imblearn\over_sampling\_smote\base.py:370: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# c:\Users\natth\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\natth\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\natth\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\natth\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\natth\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# New resampled training data shape: (19438, 56)
# New resampled label distribution:
# label
# 1.0    9719
# 0.0    9719
# Name: count, dtype: int64
#
# Training final RF model on SMOTEd data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + SMOTE) Report:
#               precision    recall  f1-score      support
# 0.0            0.876972  0.805464  0.839698  2416.000000
# 1.0            0.760326  0.845238  0.800537  1764.000000
# accuracy       0.822249  0.822249  0.822249     0.822249
# macro avg      0.818649  0.825351  0.820117  4180.000000
# weighted avg   0.827746  0.822249  0.823172  4180.000000

# %% [markdown]
# ### SMOTETomek

# %%
import json
import joblib
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.combine import SMOTETomek

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']  # 👈 *** THIS IS THE FIX ***

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply SMOTETomek to the Training Data ---
print("\nApplying SMOTETomek to the training data...")
# Note: SMOTETomek can take a bit longer than plain SMOTE
smt = SMOTETomek(random_state=42, n_jobs=-1)
X_resampled, y_resampled = smt.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")

# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on SMOTETomek data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # ⚠️ NO 'class_weight' here
    random_state=42,
    n_jobs=-1
)

# 5. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 6. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')

# IMPORTANT: Do NOT resample the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + SMOTETomek) Report:")
print(df_score_rf)
# joblib.dump(rf_model_final, './model/rf/rf_model_final_smote.pkl')
# with open('./model/rf/rf_config.json','w')as f:
#     json.dump(
#         obj=rf_model_final.get_params(),
#         fp=f,
#         indent = 4
#     )
# Out:
# Original training data shape: (16720, 56)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying SMOTETomek to the training data...
# c:\Users\natth\anaconda3\Lib\site-packages\imblearn\over_sampling\_smote\base.py:370: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# New resampled training data shape: (18440, 56)
# New resampled label distribution:
# label
# 1.0    9220
# 0.0    9220
# Name: count, dtype: int64
#
# Training final RF model on SMOTETomek data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + SMOTETomek) Report:
#               precision    recall  f1-score      support
# 0.0            0.876465  0.804636  0.839016  2416.000000
# 1.0            0.759429  0.844671  0.799785  1764.000000
# accuracy       0.821531  0.821531  0.821531     0.821531
# macro avg      0.817947  0.824653  0.819401  4180.000000
# weighted avg   0.827075  0.821531  0.822460  4180.000000

# %% [markdown]
# ### ADASYN (Adaptive Synthetic Sampling)

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.over_sampling import ADASYN  # 👈 1. Import ADASYN

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = pandas.read_csv('./data/salary.train.processed.csv').set_index('id')
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply ADASYN to the Training Data ---
print("\nApplying ADASYN to the training data...")
ada = ADASYN(random_state=42, n_jobs=-1)
X_resampled, y_resampled = ada.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")
# Note: The counts might not be perfectly equal, as ADASYN's generation is adaptive.


# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on ADASYN data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # ⚠️ NO 'class_weight' here
    random_state=42,
    n_jobs=-1
)

# 5. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 6. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = pandas.read_csv('./data/salary.test.processed.csv').set_index('id')

# IMPORTANT: Do NOT resample the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + ADASYN) Report:")
print(df_score_rf)
# Out:
# Original training data shape: (16720, 56)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying ADASYN to the training data...
# c:\Users\natth\anaconda3\Lib\site-packages\imblearn\over_sampling\_adasyn.py:156: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# New resampled training data shape: (19417, 56)
# New resampled label distribution:
# label
# 0.0    9719
# 1.0    9698
# Name: count, dtype: int64
#
# Training final RF model on ADASYN data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + ADASYN) Report:
#               precision    recall  f1-score      support
# 0.0            0.888837  0.781043  0.831461  2416.000000
# 1.0            0.742829  0.866213  0.799791  1764.000000
# accuracy       0.816986  0.816986  0.816986     0.816986
# macro avg      0.815833  0.823628  0.815626  4180.000000
# weighted avg   0.827220  0.816986  0.818096  4180.000000

# %%
data_train = pd.read_csv('./data/salary.train.processed.csv').set_index('id')
data_test = pd.read_csv('./data/salary.test.processed.csv').set_index('id')

# List of junk columns to remove
# Note: 'id' is already gone (it's the index), so we don't list it.
cols_to_drop = ['social-security-number', 'house-number', 'fnlwgt']

# Just drop them. Use errors='ignore' in case a column
# doesn't exist in one of the files (e.g., test set).
data_train = data_train.drop(columns=cols_to_drop, errors='ignore')
data_test = data_test.drop(columns=cols_to_drop, errors='ignore')

# %%
import json
import joblib
import pandas
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics
from sklearn.metrics import classification_report
from imblearn.combine import SMOTETomek

# --- 1. Load Data (Needed for training) ---
try:
    data_train_full = data_train
except FileNotFoundError:
    print("Error: ไม่พบไฟล์ salary.train.processed.csv กรุณาตรวจสอบ path")
    # exit() 

X_full = data_train_full.drop(['label'], axis='columns')
y_full = data_train_full['label']  # 👈 *** THIS IS THE FIX ***

print(f"Original training data shape: {X_full.shape}")
print(f"Original label distribution:\n{y_full.value_counts()}")

# --- 2. Define Your Best Parameters ---
# These are the params you provided from Optuna
best_rf_params = best_parameter

# --- 3. Apply SMOTETomek to the Training Data ---
print("\nApplying SMOTETomek to the training data...")
# Note: SMOTETomek can take a bit longer than plain SMOTE
smt = SMOTETomek(random_state=42, n_jobs=-1)
X_resampled, y_resampled = smt.fit_resample(X_full, y_full)

print(f"New resampled training data shape: {X_resampled.shape}")
print(f"New resampled label distribution:\n{y_resampled.value_counts()}")

# --- 4. Create and Train the Final Model (with NO class_weight) ---
print("\nTraining final RF model on SMOTETomek data...")

rf_model_final = RandomForestClassifier(
    **best_rf_params,
    # ⚠️ NO 'class_weight' here
    random_state=42,
    n_jobs=-1
)

# 5. Train the model on the NEW resampled data
rf_model_final.fit(X_resampled, y_resampled)
print("Model training complete.")

# --- 6. Evaluate on ORIGINAL Test Data ---
print("\nEvaluating model on *original* test data...")

data_test_rf = data_test

# IMPORTANT: Do NOT resample the test data.
X_test = data_test_rf.drop(['label'], axis='columns')
y_test = data_test_rf['label']

data_test_rf['prediction'] = rf_model_final.predict(X_test)

# Print the report
report_scores_rf = sklearn.metrics.classification_report(
    y_true=y_test,
    y_pred=data_test_rf['prediction'],
    digits=6,
    output_dict=True
)
df_score_rf = pandas.DataFrame(report_scores_rf).transpose()

print("\nRandom Forest (Tuned + SMOTETomek) Report:")
print(df_score_rf)
# joblib.dump(rf_model_final, './model/rf/rf_model_final_smote.pkl')
# with open('./model/rf/rf_config.json','w')as f:
#     json.dump(
#         obj=rf_model_final.get_params(),
#         fp=f,
#         indent = 4
#     )
# Out:
# Original training data shape: (16720, 53)
# Original label distribution:
# label
# 0.0    9719
# 1.0    7001
# Name: count, dtype: int64
#
# Applying SMOTETomek to the training data...
# c:\Users\natth\anaconda3\Lib\site-packages\imblearn\over_sampling\_smote\base.py:370: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# New resampled training data shape: (19186, 53)
# New resampled label distribution:
# label
# 1.0    9593
# 0.0    9593
# Name: count, dtype: int64
#
# Training final RF model on SMOTETomek data...
# Model training complete.
#
# Evaluating model on *original* test data...
#
# Random Forest (Tuned + SMOTETomek) Report:
#               precision    recall  f1-score      support
# 0.0            0.883212  0.801325  0.840278  2416.000000
# 1.0            0.758551  0.854875  0.803838  1764.000000
# accuracy       0.823923  0.823923  0.823923     0.823923
# macro avg      0.820881  0.828100  0.822058  4180.000000
# weighted avg   0.830604  0.823923  0.824900  4180.000000
