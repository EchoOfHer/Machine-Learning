# %%
selected_features = ['marital-status_married-civ-spouse', 'relationship_husband', 'marital-status_never-married', 'education-num', 'capitalgain', 'age-group', 'relationship_own-child', 'hoursperweek', 'sex_male', 'relationship_not-in-family', 'occupation_prof-specialty', 'occupation_other-service', 'relationship_unmarried', 'marital-status_divorced', 'capitalloss', 'occupation_exec-managerial', 'workclass_self-emp-inc', 'relationship_wife', 'workclass_private', 'race_black', 'race_white', 'relationship_other-relative', 'occupation_handlers-cleaners']

# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %%
data_test = pandas.read_csv('../data/salary.live.processed.csv').set_index('id')
data_test = data_test[selected_features]  # Use only selected features
data_test
# Out:
#        marital-status_married-civ-spouse  relationship_husband  \
# id
# 6111                                 1.0                   1.0
# 11214                                0.0                   0.0
# 5554                                 1.0                   1.0
# 25131                                1.0                   1.0
# 14324                                1.0                   1.0
# ...                                  ...                   ...
# 25998                                1.0                   1.0
# 8375                                 1.0                   1.0
# 13888                                0.0                   0.0
# 4159                                 1.0                   1.0
# 9658                                 0.0                   0.0
#
#        marital-status_never-married  education-num  capitalgain  age-group  \
# id
# 6111                            0.0            7.0          0.0        0.0
# ...

# %%
model = joblib.load('../model/RF/rf_model_final_smote.joblib')
model
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=12,
#                        max_features=0.42082357754585725, min_samples_leaf=2,
#                        min_samples_split=9, n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
model.predict(X = data_test)
# Out:
# array([0., 0., 1., ..., 0., 1., 0.])

# %%
data_test['prediction']=model.predict(
X = data_test,
)
data_test
# Out:
#        marital-status_married-civ-spouse  relationship_husband  \
# id
# 6111                                 1.0                   1.0
# 11214                                0.0                   0.0
# 5554                                 1.0                   1.0
# 25131                                1.0                   1.0
# 14324                                1.0                   1.0
# ...                                  ...                   ...
# 25998                                1.0                   1.0
# 8375                                 1.0                   1.0
# 13888                                0.0                   0.0
# 4159                                 1.0                   1.0
# 9658                                 0.0                   0.0
#
#        marital-status_never-married  education-num  capitalgain  age-group  \
# id
# 6111                            0.0            7.0          0.0        0.0
# ...

# %%
prediction_counts = data_test['prediction'].value_counts()
prediction_counts
# Out:
# prediction
# 0.0    3665
# 1.0    3302
# Name: count, dtype: int64
