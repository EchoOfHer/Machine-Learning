# %%
drop_features = [ 'social-security-number', 'house-number', 'fnlwgt']

# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %%
data_test = pandas.read_csv('../data/salary.live.processed.csv').set_index('id')
data_test = data_test.drop(columns=drop_features)  # Use only selected features
data_test
# Out:
#        age-group  education-num  capitalgain  capitalloss  hoursperweek  \
# id
# 6111         0.0            7.0          0.0          0.0           2.0
# 11214        1.0            9.0          0.0          0.0           1.0
# 5554         4.0            9.0          0.0          0.0           3.0
# 25131        2.0           14.0          0.0          0.0           2.0
# 14324        3.0            9.0          0.0          0.0           2.0
# ...          ...            ...          ...          ...           ...
# 25998        4.0           13.0          0.0          0.0           3.0
# 8375         4.0            9.0          0.0          0.0           4.0
# 13888        1.0            7.0          0.0          0.0           1.0
# 4159         1.0           14.0          0.0          0.0           2.0
# 9658         0.0           10.0          0.0          0.0           2.0
#
#        native-country_united-states  native-country_Other  \
# id
# ...

# %%
model = joblib.load('../model/lgbm/lgbm_model_final_smote.joblib')
model
# Out:
# LGBMClassifier(colsample_bytree=0.7550416705324272,
#                learning_rate=0.26992371517621444, max_depth=5, n_estimators=102,
#                n_jobs=-1, num_leaves=22, random_state=42,
#                reg_alpha=8.715022016449311e-06, reg_lambda=3.587506772725946,
#                scale_pos_weight=np.float64(1.3882302528210255),
#                subsample=0.9863285464013338)

# %%
model.predict(X = data_test)
# Out:
# array([0., 0., 1., ..., 0., 1., 0.])

# %%
data_test['prediction']=model.predict(
X = data_test,
)
data_test
# Out:
#        age-group  education-num  capitalgain  capitalloss  hoursperweek  \
# id
# 6111         0.0            7.0          0.0          0.0           2.0
# 11214        1.0            9.0          0.0          0.0           1.0
# 5554         4.0            9.0          0.0          0.0           3.0
# 25131        2.0           14.0          0.0          0.0           2.0
# 14324        3.0            9.0          0.0          0.0           2.0
# ...          ...            ...          ...          ...           ...
# 25998        4.0           13.0          0.0          0.0           3.0
# 8375         4.0            9.0          0.0          0.0           4.0
# 13888        1.0            7.0          0.0          0.0           1.0
# 4159         1.0           14.0          0.0          0.0           2.0
# 9658         0.0           10.0          0.0          0.0           2.0
#
#        native-country_united-states  native-country_Other  \
# id
# ...

# %%
prediction_counts = data_test['prediction'].value_counts()
prediction_counts
# Out:
# prediction
# 0.0    3621
# 1.0    3346
# Name: count, dtype: int64

# %%
data_test['prediction']
# Out:
# id
# 6111     0.0
# 11214    0.0
# 5554     1.0
# 25131    1.0
# 14324    1.0
#         ...
# 25998    1.0
# 8375     0.0
# 13888    0.0
# 4159     1.0
# 9658     0.0
# Name: prediction, Length: 6967, dtype: float64

# %%
df_report = pandas.DataFrame(
    data=data_test['prediction'],
    columns=['prediction'],
    index=data_test.index
)
df_report
# Out:
#        prediction
# id
# 6111          0.0
# 11214         0.0
# 5554          1.0
# 25131         1.0
# 14324         1.0
# ...           ...
# 25998         1.0
# 8375          0.0
# 13888         0.0
# 4159          1.0
# 9658          0.0
#
# [6967 rows x 1 columns]

# %% [markdown]
# D:\Machine Learning\ML_P\reult

# %%
df_report.to_csv('./lgbm_test_report.csv', index=True)

# %%
data_live = pandas.read_csv('../data/salary.live.processed.csv').set_index('id')
data_live
# Out:
#        age-group  education-num  capitalgain  capitalloss  hoursperweek  \
# id
# 6111         0.0            7.0          0.0          0.0           2.0
# 11214        1.0            9.0          0.0          0.0           1.0
# 5554         4.0            9.0          0.0          0.0           3.0
# 25131        2.0           14.0          0.0          0.0           2.0
# 14324        3.0            9.0          0.0          0.0           2.0
# ...          ...            ...          ...          ...           ...
# 25998        4.0           13.0          0.0          0.0           3.0
# 8375         4.0            9.0          0.0          0.0           4.0
# 13888        1.0            7.0          0.0          0.0           1.0
# 4159         1.0           14.0          0.0          0.0           2.0
# 9658         0.0           10.0          0.0          0.0           2.0
#
#        social-security-number  house-number    fnlwgt  \
# id
# ...
